# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# '/Users/jamyarrahman/Code/Data Scince and Machine Learing/pandas'

# %%
df = pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_Output', index=False)

# %%
pd.read_csv('My_Output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
 df.to_excel('Output_Excel_Sample2.xlsx',sheet_name='NewSheet')
# Out:
# <ipython-input-8-73075418f2c6>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   df.to_excel('Output_Excel_Sample2.xlsx',sheet_name='NewSheet')

# %%
pd.read_excel('Output_Excel_Sample2.xlsx',sheet_name='NewSheet')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %% [markdown]
# # Read Data from html

# %%
data = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
from sqlalchemy import create_engine

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
engine = create_engine('sqlite:///:memory:')
df.to_sql('my_table', engine, if_exists='replace')
# sqldf = pd.read_sql('my_table',con=engine)
# Out:
# 4

# %%
sqldf = pd.read_sql('my_table',con=engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
Making sql of the

# %%
data[0].to_sql('my_table2', engine, if_exists='replace')
sqldf2 = pd.read_sql('my_table2',con=engine)

# %%
sqldf2
# Out:
#     index                                          Bank Name  \
# 0       0                       The Santa Anna National Bank
# 1       1                               Pulaski Savings Bank
# 2       2                 The First National Bank of Lindsay
# 3       3              Republic First Bank dba Republic Bank
# 4       4                                      Citizens Bank
# 5       5                           Heartland Tri-State Bank
# 6       6                                First Republic Bank
# 7       7                                     Signature Bank
# 8       8                                Silicon Valley Bank
# 9       9                                  Almena State Bank
# 10     10                         First City Bank of Florida
# 11     11                               The First State Bank
# 12     12                                 Ericson State Bank
# 13     13                   City National Bank of New Jersey
# ...
